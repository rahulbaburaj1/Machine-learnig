# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulbaburaj1/rahul/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

users=pd.read_csv(r'/content/drive/MyDrive/Project4/users.dat',sep="::",engine='python',names=['UserID','Gender','Age','Occupation','Zip-code'])

ratings=pd.read_csv(r'/content/drive/MyDrive/Project4/ratings.dat',sep="::",engine='python',names=['UserID','MovieID','Rating','Timestamp'])
movies=pd.read_csv(r'/content/drive/MyDrive/Project4/movies.dat',sep="::",engine='python',encoding='latin',names=['MovieID','Title','Genres'])

# %%
movies.head()
# Out:
#    MovieID                               Title                        Genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
users.head()
# Out:
#    UserID Gender  Age  Occupation Zip-code
# 0       1      F    1          10    48067
# 1       2      M   56          16    70072
# 2       3      M   25          15    55117
# 3       4      M   45           7    02460
# 4       5      M   25          20    55455

# %%
ratings.head()
# Out:
#    UserID  MovieID  Rating  Timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291

# %%
# %matplotlib inline
ratings.hist(column='Rating')#	Visualize overall rating by users
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6f7c8507c0>]],
#       dtype=object)

# %%
# %matplotlib inline
users.hist(column='Age')##•	Visualize user age distribution
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6f8505d580>]],
#       dtype=object)

# %%
highlyrated=ratings['Rating']>=4.0
ratings[highlyrated][1:25]
# Out:
#     UserID  MovieID  Rating  Timestamp
# 3        1     3408       4  978300275
# 4        1     2355       5  978824291
# 6        1     1287       5  978302039
# 7        1     2804       5  978300719
# 8        1      594       4  978302268
# 9        1      919       4  978301368
# 10       1      595       5  978824268
# 11       1      938       4  978301752
# 12       1     2398       4  978302281
# 13       1     2918       4  978302124
# 14       1     1035       5  978301753
# 15       1     2791       4  978302188
# 17       1     2018       4  978301777
# 18       1     3105       5  978301713
# 19       1     2797       4  978302039
# 22       1     1270       5  978300055
# 23       1      527       5  978824195
# 25       1       48       5  978824351
# 26       1     1097       4  978301953
# 27       1     1721       4  978300055
# 28       1     1545       4  978824139
# 30       1     2294       4  978824291
# 31       1     3186       4  978300019
# ...

# %%
merged1= movies.merge(ratings, how='outer')

# %%
merged2= users.merge(ratings, how='outer')

# %%
merged3= merged1.merge(merged2, how='inner')

# %%
merged3.head()
# Out:
#    MovieID             Title                       Genres  UserID  Rating  \
# 0        1  Toy Story (1995)  Animation|Children's|Comedy     1.0     5.0
# 1        1  Toy Story (1995)  Animation|Children's|Comedy     6.0     4.0
# 2        1  Toy Story (1995)  Animation|Children's|Comedy     8.0     4.0
# 3        1  Toy Story (1995)  Animation|Children's|Comedy     9.0     5.0
# 4        1  Toy Story (1995)  Animation|Children's|Comedy    10.0     5.0
#
#      Timestamp Gender  Age  Occupation Zip-code
# 0  978824268.0      F    1          10    48067
# 1  978237008.0      F   50           9    55117
# 2  978233496.0      M   25          12    11413
# 3  978225952.0      M   25          17    61614
# 4  978226474.0      F   35           1    95370

# %%
merged3.UserID = merged3.UserID.astype(int)
merged3.Rating = merged3.Rating.astype(int)

# %%
merged3.sort_values(by=['UserID'], ascending=True)
# Out:
#         MovieID                               Title  \
# 0             1                    Toy Story (1995)
# 310576     1207        To Kill a Mockingbird (1962)
# 341051     1246           Dead Poets Society (1989)
# 745569     2762             Sixth Sense, The (1999)
# 144754      531           Secret Garden, The (1993)
# ...         ...                                 ...
# 835749     3108             Fisher King, The (1991)
# 149802      541                 Blade Runner (1982)
# 917912     3505                   No Way Out (1987)
# 881053     3334                    Key Largo (1948)
# 100415      357  Four Weddings and a Funeral (1994)
#
#                                 Genres  UserID  Rating    Timestamp Gender  \
# 0          Animation|Children's|Comedy       1       5  978824268.0      F
# 310576                           Drama       1       4  978300719.0      F
# 341051                           Drama       1       4  978302091.0      F
# ...

# %%
cols = list(merged3.columns.values)

# %%
print(cols)
# Out:
# ['MovieID', 'Title', 'Genres', 'UserID', 'Rating', 'Timestamp', 'Gender', 'Age', 'Occupation', 'Zip-code']

# %%
main=merged3[['UserID', 'MovieID', 'Title', 'Rating', 'Genres', 'Zip-code', 'Gender', 'Age', 'Occupation', 'Timestamp']]

# %%
main.head()
# Out:
#    UserID  MovieID             Title  Rating                       Genres  \
# 0       1        1  Toy Story (1995)       5  Animation|Children's|Comedy
# 1       6        1  Toy Story (1995)       4  Animation|Children's|Comedy
# 2       8        1  Toy Story (1995)       4  Animation|Children's|Comedy
# 3       9        1  Toy Story (1995)       5  Animation|Children's|Comedy
# 4      10        1  Toy Story (1995)       5  Animation|Children's|Comedy
#
#   Zip-code Gender  Age  Occupation    Timestamp
# 0    48067      F    1          10  978824268.0
# 1    55117      F   50           9  978237008.0
# 2    11413      M   25          12  978233496.0
# 3    61614      M   25          17  978225952.0
# 4    95370      F   35           1  978226474.0

# %%
main[main['MovieID'] == 1].hist(column='Rating')##•	Find and visualize the user rating of the movie “Toy Story”
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6f7c893df0>]],
#       dtype=object)

# %%
main[main['MovieID'] == 1].hist(column='Age')##•	Find and visualize the viewership of the movie “Toy Story” by age group
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6f84d70c40>]],
#       dtype=object)

# %%
top_25 = main[25:]
top_25['Rating'].value_counts().plot(kind='barh',alpha=0.6,figsize=(5,5))
##•	Find and visualize the top 25 movies by viewership rating

# %%
user2696 = main[main['UserID'] == 2696]

# %%
user2696
# Out:
#         UserID  MovieID                                           Title  \
# 95261     2696      350                              Client, The (1994)
# 200536    2696      800                                Lone Star (1996)
# 270342    2696     1092                           Basic Instinct (1992)
# 274576    2696     1097               E.T. the Extra-Terrestrial (1982)
# 349333    2696     1258                             Shining, The (1980)
# 360382    2696     1270                       Back to the Future (1985)
# 448293    2696     1589                                 Cop Land (1997)
# 457193    2696     1617                        L.A. Confidential (1997)
# 459835    2696     1625                                Game, The (1997)
# 464473    2696     1644          I Know What You Did Last Summer (1997)
# 465069    2696     1645                    Devil's Advocate, The (1997)
# 480658    2696     1711  Midnight in the Garden of Good and Evil (1997)
# ...

# %%
user2696.hist(column='Rating')##Visualize the rating data by user of user id = 2696
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6f87502970>]],
#       dtype=object)

# %%
labels = ['0-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79']
main['age_group'] = pd.cut(main.Age, range(0, 81, 10), right=False, labels=labels)
main[['Age', 'age_group']].drop_duplicates()[:10]
# Out:
# <ipython-input-31-75e3e6fc4f94>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main['age_group'] = pd.cut(main.Age, range(0, 81, 10), right=False, labels=labels)
#     Age age_group
# 0     1       0-9
# 1    50     50-59
# 2    25     20-29
# 4    35     30-39
# 5    18     10-19
# 14   45     40-49
# 27   56     50-59

# %%
groupedby_Title = main.groupby('Title')

# %%
ToyStory_data = groupedby_Title.get_group('Toy Story 2 (1999)')
ToyStory_data.shape
# Out:
# (1585, 11)

# %%
ToyStory_data[['Title','age_group']]##•	Find and visualize the viewership of the movie “Toy Story” by age group
# Out:
#                      Title age_group
# 836694  Toy Story 2 (1999)       0-9
# 836695  Toy Story 2 (1999)     20-29
# 836696  Toy Story 2 (1999)     20-29
# 836697  Toy Story 2 (1999)     30-39
# 836698  Toy Story 2 (1999)     50-59
# ...                    ...       ...
# 838274  Toy Story 2 (1999)     20-29
# 838275  Toy Story 2 (1999)     20-29
# 838276  Toy Story 2 (1999)     10-19
# 838277  Toy Story 2 (1999)     20-29
# 838278  Toy Story 2 (1999)     40-49
#
# [1585 rows x 2 columns]

# %%
first_500 = main[500:]
first_500.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
features = first_500[['MovieID','Age','Occupation']].values

# %%
labels = first_500[['Rating']].values

# %%
main.Age.plot.hist(bins=25)
plt.title("Movie & Rating")
plt.ylabel('MovieID')
plt.xlabel('Ratings')##hist movie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-8c33b4a5fdd7> in <module>
#       1 main.Age.plot.hist(bins=25)
# ----> 2 plt.title("Movie & Rating")
#       3 plt.ylabel('MovieID')
#       4 plt.xlabel('Ratings')
#
# NameError: name 'plt' is not defined

# %%
main.Age.plot.hist(bins=25)
plt.title("Age & Rating")
plt.ylabel('Age')
plt.xlabel('Ratings')##age
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-75131541a9c5> in <module>
#       1 main.Age.plot.hist(bins=25)
# ----> 2 plt.title("Age & Rating")
#       3 plt.ylabel('Age')
#       4 plt.xlabel('Ratings')
#
# NameError: name 'plt' is not defined

# %%
main.Age.plot.hist(bins=25)
plt.title("Occupation & Rating")
plt.ylabel('Occupation')
plt.xlabel('Ratings')##occ hsist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-a27f5df55706> in <module>
#       1 main.Age.plot.hist(bins=25)
# ----> 2 plt.title("Occupation & Rating")
#       3 plt.ylabel('Occupation')
#       4 plt.xlabel('Ratings')##occ hsist
#
# NameError: name 'plt' is not defined
